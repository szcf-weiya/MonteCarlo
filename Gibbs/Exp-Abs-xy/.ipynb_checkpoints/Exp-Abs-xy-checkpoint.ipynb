# %% [markdown]
# # Simulation
#
# Target distribution:
#
# $$
# f(x, y)\propto \exp(-\vert x\vert -\vert y\vert - a\vert y-x\vert)\,.
# $$
#
# Gibbs:
#
# - $f(x\mid y)\propto \exp(-\vert x\vert - a\vert y-x\vert)$
# - $f(y\mid x)\propto \exp(-\vert y\vert - a\vert y-x\vert)$

# %% [markdown]
# ### Accept-Reject
#
# $$
# f(x\mid y)\propto \exp(-\vert x\vert - a\vert y-x\vert)\le \exp(-a\vert x - y\vert)
# $$

# %%
using Distributions

# %%
a = 3
f(x, y) = exp( -abs(x) - a * abs(y-x) )
g(x, y) = exp(-a * abs(x-y))

function gibbs_ar(N::Int)
    x = ones(N+1)
    y = ones(N+1)
    for i = 2:(N+1)
        xstar = rand(Laplace(y[i-1], 1/a))
        if rand() < f(xstar, y[i-1]) / g(xstar, y[i-1])
            x[i] = xstar
        else
            x[i] = x[i-1]
        end
        
        ystar = rand(Laplace(x[i], 1/a))
        if rand() < f(x[i], ystar) / g(x[i], ystar)
            y[i] = ystar
        else
            y[i] = y[i-1]
        end
    end
    return x, y
end
# Out:
# gibbs_ar (generic function with 1 method)

# %%
x, y = gibbs_ar(1000)
# Out:
# ([1.0, 1.0, 1.0, 1.0, 0.642794, -0.0582107, -0.0582107, -0.0582107, 0.0835292, 0.834245  …  0.919978, 0.919978, 0.919978, 0.283775, 1.63684, 1.63684, 1.63684, 1.63684, 1.4475, 1.4475], [1.0, 1.0, 1.0, 1.29302, 0.101057, 0.55634, -0.731774, -0.357957, 0.479283, 0.479283  …  1.15247, 0.787157, 0.679497, 0.679497, 0.679497, 0.679497, 0.679497, 1.43845, 1.43845, 1.43845])

# %%
using Plots
plot(x, y, seriestype = :scatter, legend = false)

# %% [markdown]
# ## Inverse CDF
#
# Refer to the handwritten supplementary for more derivation.

# %%
function one_gibbs(y)
    p1 = exp(-a*y) * ( exp((a-1)*y) - 1 ) / (a - 1) * (y >= 0)
    p2 = exp(-a*y) * ( exp((a+1)*min(0, y)) - 1 ) / (a + 1)
    p3 = exp(a*y) * ( exp(-(1+a)*max(0, y)) - 1 ) / (a + 1)
    p4 = exp(a*y) * ( exp((1-a)*y) - 1) / (a - 1) * (y < 0)
    flag = sample(1:4, pweights(p1, p2, p3, p4))
    u = rand()
    if flag == 1
        x = log( 1 + u * ( exp((a-1)*y) - 1 ) ) / (a - 1)
    elseif flag == 2
        x = log(u) / (a + 1) + min(0, y)
    elseif flag == 3
        x = log(u) / (a + 1) + max(0, y)
    else
        x = log( 1 - u * ( 1 - exp((1-a)*y) ) ) / (1 - a)
    end
    return x
end

function gibbs_inv(N::Int)
    x = ones(N+1)
    y = ones(N+1)
    for i = 2:(N+1)
        x[i] = one_gibbs(y[i-1])
        y[i] = one_gibbs(x[i])
    end
end
